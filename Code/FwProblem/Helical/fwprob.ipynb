# %%
import numpy as np
import pandas as pd

# %%
#Load sensor positions file
data_sensorpos = pd.read_csv(Hall_sensor_positions.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1953703563.py in <cell line: 0>()
#       1 #Load sensor positions file
# ----> 2 data_sensorpos = pd.read_csv(Hall_sensor_positions.csv)
#
# NameError: name 'Hall_sensor_positions' is not defined
